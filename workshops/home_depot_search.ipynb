# %%
import pandas as pd

df_train = pd.read_csv('https://elephantscale-public.s3.amazonaws.com/data/home-depot-product-search-relevance/train.csv')
df_test = pd.read_csv('https://elephantscale-public.s3.amazonaws.com/data/home-depot-product-search-relevance/test.csv')
df_train
# Out:
#            id  product_uid  ...                              search_term relevance
# 0           2       100001  ...                            angle bracket      3.00
# 1           3       100001  ...                                l bracket      2.50
# 2           9       100002  ...                                deck over      3.00
# 3          16       100005  ...                         rain shower head      2.33
# 4          17       100005  ...                       shower only faucet      2.67
# ...       ...          ...  ...                                      ...       ...
# 74062  221457       206638  ...                           tv riser glass      1.00
# 74063  221458       206639  ...                        r20 halogen light      3.00
# 74064  221463       206641  ...  schlage lock siena half dummy knob with      2.33
# 74065  221471       206648  ...                        zen garden  decor      3.00
# ...

# %%
attributes = pd.read_csv('https://elephantscale-public.s3.amazonaws.com/data/home-depot-product-search-relevance/attributes.csv')
attributes
# Out:
#          product_uid  ...                                              value
# 0           100001.0  ...  Versatile connector for various 90° connection...
# 1           100001.0  ...  Stronger than angled nailing or screw fastenin...
# 2           100001.0  ...  Help ensure joints are consistently straight a...
# 3           100001.0  ...              Dimensions: 3 in. x 3 in. x 1-1/2 in.
# 4           100001.0  ...                           Made from 12-Gauge steel
# ...              ...  ...                                                ...
# 2044798     224428.0  ...                                                 No
# 2044799     224428.0  ...                                Drill & Router Bits
# 2044800     224428.0  ...                                             3/8 in
# 2044801     224428.0  ...                                                Hex
# 2044802     224428.0  ...                                         Power Tool
#
# [2044803 rows x 3 columns]

# %%
product_descriptions = pd.read_csv('https://elephantscale-public.s3.amazonaws.com/data/home-depot-product-search-relevance/product_descriptions.csv')
product_descriptions
# Out:
#         product_uid                                product_description
# 0            100001  Not only do angles make joints stronger, they ...
# 1            100002  BEHR Premium Textured DECKOVER is an innovativ...
# 2            100003  Classic architecture meets contemporary design...
# 3            100004  The Grape Solar 265-Watt Polycrystalline PV So...
# 4            100005  Update your bathroom with the Delta Vero Singl...
# ...             ...                                                ...
# 124423       224424  Create a neat yet stylish storage space for or...
# 124424       224425  Our Bullnose Adirondack Chair Cushions fit Adi...
# 124425       224426  Joist hangers are designed to provide support ...
# 124426       224427  These socket cap screws are ideal for applicat...
# 124427       224428  The Bosch quick change bi-metal hole saws feat...
#
# [124428 rows x 2 columns]
